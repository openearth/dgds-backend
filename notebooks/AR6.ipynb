# %%
import geojson
import netCDF4 as nc
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
folder = r'p:\11205479-coclico\data\17_AR6_SLP_IPCC\IPCC_AR6_slp_regional\AR6_Projections\Regional\medium_confidence'
dataset = r'ssp245\total_ssp245_medium_confidence_rates.nc'
ds = nc.Dataset(os.path.join(folder, dataset))
print(ds)
#ds['years'][:]
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     description: Combined confidence output file for AR6 sea-level change projections
#     history: Created Sat Jul 10 15:42:06 2021
#     source: Files Combined: /projects/kopp/ar6/regional/pboxes_rates/pb_1f/ssp245/total-workflow_rates.nc
#     dimensions(sizes): locations(66190), years(14), quantiles(107)
#     variables(dimensions): float32 lat(locations), float32 lon(locations), int32 locations(locations), int32 years(years), float32 quantiles(quantiles), int16 sea_level_change_rate(quantiles, years, locations)
#     groups:

# %%
plt.figure(figsize=(16,9))
plt.scatter(ds['lon'][:], ds['lat'][:], s=1)
#plt.scatter(ds['longitude'][2000:2100], ds['latitude'][2000:2100], s=1, c='r')
plt.xlim(-10,50)
plt.ylim(25,75)
plt.grid()
